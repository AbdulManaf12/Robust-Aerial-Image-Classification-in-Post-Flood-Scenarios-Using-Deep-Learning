# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Focus/Code'
# %ls
# Out:
# /content/drive/MyDrive/Focus/Code
#  data_preprocessing.ipynb  'DenseNet(169)_A.ipynb'

# %%
import os
import pickle
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.utils import Sequence
from keras.models import Sequential
from keras.models import load_model
from keras.optimizers import Adam
from keras.applications import DenseNet169
from keras.layers import Dense, GlobalAveragePooling2D, Flatten, Dropout, Input
from sklearn.metrics import confusion_matrix, classification_report

# %%
batch_size = 32
dataset_code = 'A'
model_name = 'DenseNet169'
data_saved_dir = r'/content/drive/MyDrive/Focus/Dataset'
model_saved_dir = r'/content/drive/MyDrive/Focus/Models'
train_data_path = f'{data_saved_dir}/A_training.pkl'
val_data_path = f'{data_saved_dir}/A_validation.pkl'
test_data_path = f'{data_saved_dir}/A_testing.pkl'

# %%
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        data = pickle.load(f)
    return data

train_images, train_labels = load_pickle(train_data_path)
val_images, val_labels = load_pickle(val_data_path)
test_images, test_labels = load_pickle(test_data_path)

print(f'Training images: {train_images.shape}')
print(f'Validation images: {val_images.shape}')
print(f'Testing images: {test_images.shape}')
# Out:
# Training images: (3718, 256, 256, 3)
# Validation images: (795, 256, 256, 3)
# Testing images: (801, 256, 256, 3)

# %%
class CustomDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.images))

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_images = self.images[start:end]
        batch_labels = self.labels[start:end]
        return batch_images, batch_labels

train_data_generator = CustomDataGenerator(train_images, train_labels, batch_size)
val_data_generator = CustomDataGenerator(val_images, val_labels, batch_size)
test_data_generator = CustomDataGenerator(test_images, test_labels, batch_size)

# %%
efficient_net = DenseNet169(
    weights='imagenet',
    input_shape=(256,256,3),
    include_top=False,
    pooling='max'
)

model = Sequential()
model.add(Input(shape=(256, 256, 3)))
model.add(efficient_net)
model.add(Dense(units = 120, activation='relu'))
model.add(Dense(units = 120, activation = 'relu'))
model.add(Dense(units = 1, activation='sigmoid'))
model.compile(optimizer='Adam', loss='binary_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ densenet169 (Functional)             │ (None, 1664)                │      12,642,880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 120)                 │         199,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 120)                 │          14,520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             121 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,857,321 (49.05 MB)
#  Trainable params: 12,698,921 (48.44 MB)
#  Non-trainable params: 158,400 (618.75 KB)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
import os

model_dir = f'{model_saved_dir}\\{dataset_code}_{model_name}'
if not os.path.exists(model_dir):
    os.makedirs(model_dir)
else:
    print(f'{model_dir} already exists')

filename = 'weights-improvement-{epoch:02d}-{val_accuracy:.2f}'
# Change the file extension to .keras
filepath = f'{model_dir}\\{dataset_code}_{model_name}-{filename}.keras'

# Define the ModelCheckpoint with the corrected filepath
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')

# Define early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=3, verbose=1)

# Add callbacks to the list
callbacks_list = [checkpoint, early_stop]

# %%
history = model.fit(train_data_generator, epochs=50, validation_data=val_data_generator, callbacks = callbacks_list)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9121 - loss: 0.2943
# Epoch 1: val_accuracy improved from -inf to 0.88553, saving model to /content/drive/MyDrive/Focus/Models\A_DenseNet169\A_DenseNet169-weights-improvement-01-0.89.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 668s 3s/step - accuracy: 0.9122 - loss: 0.2935 - val_accuracy: 0.8855 - val_loss: 1.2690
# Epoch 2/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.9278 - loss: 0.1814
# Epoch 2: val_accuracy improved from 0.88553 to 0.90692, saving model to /content/drive/MyDrive/Focus/Models\A_DenseNet169\A_DenseNet169-weights-improvement-02-0.91.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 59s 503ms/step - accuracy: 0.9279 - loss: 0.1812 - val_accuracy: 0.9069 - val_loss: 0.4858
# Epoch 3/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9432 - loss: 0.1377
# Epoch 3: val_accuracy improved from 0.90692 to 0.94843, saving model to /content/drive/MyDrive/Focus/Models\A_DenseNet169\A_DenseNet169-weights-improvement-03-0.95.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 82s 503ms/step - accuracy: 0.9433 - loss: 0.1377 - val_accuracy: 0.9484 - val_loss: 0.2936
# Epoch 4/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step - accuracy: 0.9614 - loss: 0.1164
# Epoch 4: val_accuracy did not improve from 0.94843
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 57s 488ms/step - accuracy: 0.9614 - loss: 0.1164 - val_accuracy: 0.9421 - val_loss: 0.2529
# Epoch 5/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9555 - loss: 0.1116
# Epoch 5: val_accuracy did not improve from 0.94843
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 80s 474ms/step - accuracy: 0.9556 - loss: 0.1115 - val_accuracy: 0.9358 - val_loss: 0.1772
# Epoch 6/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.9691 - loss: 0.0842
# Epoch 6: val_accuracy did not improve from 0.94843
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 82s 473ms/step - accuracy: 0.9690 - loss: 0.0843 - val_accuracy: 0.9031 - val_loss: 0.5308
# Epoch 7/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step - accuracy: 0.9745 - loss: 0.0836
# Epoch 7: val_accuracy did not improve from 0.94843
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 55s 465ms/step - accuracy: 0.9746 - loss: 0.0835 - val_accuracy: 0.9283 - val_loss: 0.3527
# Epoch 8/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.9827 - loss: 0.0424
# Epoch 8: val_accuracy improved from 0.94843 to 0.97233, saving model to /content/drive/MyDrive/Focus/Models\A_DenseNet169\A_DenseNet169-weights-improvement-08-0.97.keras
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 86s 499ms/step - accuracy: 0.9826 - loss: 0.0426 - val_accuracy: 0.9723 - val_loss: 0.0771
# Epoch 9/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step - accuracy: 0.9729 - loss: 0.0744
# Epoch 9: val_accuracy did not improve from 0.97233
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 55s 465ms/step - accuracy: 0.9728 - loss: 0.0748 - val_accuracy: 0.8943 - val_loss: 0.7603
# Epoch 10/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9476 - loss: 0.1517
# Epoch 10: val_accuracy did not improve from 0.97233
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 83s 471ms/step - accuracy: 0.9476 - loss: 0.1516 - val_accuracy: 0.9459 - val_loss: 0.1263
# Epoch 11/50
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.9553 - loss: 0.1149
# Epoch 11: val_accuracy did not improve from 0.97233
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 84s 488ms/step - accuracy: 0.9554 - loss: 0.1148 - val_accuracy: 0.9535 - val_loss: 0.1172
# Epoch 11: early stopping

# %%
plt.figure(figsize=(8,8))
plt.plot(history.history['loss'], color='b', label="Training loss")
plt.plot(history.history['val_loss'], color='r', label="Validation loss")
plt.legend()
plt.show()

plt.figure()

plt.figure(figsize=(8,8))
plt.plot(history.history['accuracy'], color='b', label="Training accuracy")
plt.plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
plt.legend()
plt.ylim(0.5, 1)
plt.show()

# %% [markdown]
# #### Testing on model till Last Epoch

# %%
predictions = model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 32s 743ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97       712
#            1       0.73      0.93      0.82        89
#
#     accuracy                           0.96       801
#    macro avg       0.86      0.95      0.90       801
# weighted avg       0.96      0.96      0.96       801

# %% [markdown]
# #### Testing on model which is last best saved

# %%
models = sorted(os.listdir(model_dir))

for file in models[:-1]:
    os.remove(f'{model_dir}\{file}')

print(os.listdir(model_dir))
best_model = load_model(f'{model_dir}\{models[-1]}')
print('Best model loaded ...')

predictions = best_model.predict(test_data_generator)

predicted_labels = (predictions > 0.5).astype(int)

conf_matrix = confusion_matrix(test_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Non Flooded', 'Flooded'], yticklabels=['Non Flooded', 'Flooded'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

print("Classification Report:")
print(classification_report(test_labels, predicted_labels))
# Out:
# Best model loaded ...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 25s 542ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.95      0.97       712
#            1       0.71      0.89      0.79        89
#
#     accuracy                           0.95       801
#    macro avg       0.85      0.92      0.88       801
# weighted avg       0.95      0.95      0.95       801
